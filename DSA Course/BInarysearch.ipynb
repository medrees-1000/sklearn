# %%
def locate_card(cards, query):
    pass

# %%
test = {
    'input': { 
        'cards': [13, 11, 10, 7, 4, 3, 1, 0], 
        'query': 7
    },
    'output': 3
}

# %%
locate_card(**test['input']) == test['output']
# Out:
# False

# %%
tests = []

# %%
# query occurs in the middle
tests.append(test)

tests.append({
    'input': {
        'cards': [13, 11, 10, 7, 4, 3, 1, 0],
        'query': 1
    },
    'output': 6
})

# %%
# query is the first element
tests.append({
    'input': {
        'cards': [4, 2, 1, -1],
        'query': 4
    },
    'output': 0
})

# %%
# query is the last element
tests.append({
    'input': {
        'cards': [3, -1, -9, -127],
        'query': -127
    },
    'output': 3
})

# %%
# cards contains just one element, query
tests.append({
    'input': {
        'cards': [6],
        'query': 6
    },
    'output': 0 
})

# %%
# cards does not contain query 
tests.append({
    'input': {
        'cards': [9, 7, 5, 2, -9],
        'query': 4
    },
    'output': -1
})

# %%
# cards is empty
tests.append({
    'input': {
        'cards': [],
        'query': 7
    },
    'output': -1
})

# %%
# numbers can repeat in cards
tests.append({
    'input': {
        'cards': [8, 8, 6, 6, 6, 6, 6, 3, 2, 2, 2, 0, 0, 0],
        'query': 3
    },
    'output': 7
})

# %%
# query occurs multiple times
tests.append({
    'input': {
        'cards': [8, 8, 6, 6, 6, 6, 6, 6, 3, 2, 2, 2, 0, 0, 0],
        'query': 6
    },
    'output': 2
})

# %%
tests
# Out:
# [{'input': {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 7}, 'output': 3},
#  {'input': {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 1}, 'output': 6},
#  {'input': {'cards': [4, 2, 1, -1], 'query': 4}, 'output': 0},
#  {'input': {'cards': [3, -1, -9, -127], 'query': -127}, 'output': 3},
#  {'input': {'cards': [6], 'query': 6}, 'output': 0},
#  {'input': {'cards': [9, 7, 5, 2, -9], 'query': 4}, 'output': -1},
#  {'input': {'cards': [], 'query': 7}, 'output': -1},
#  {'input': {'cards': [8, 8, 6, 6, 6, 6, 6, 3, 2, 2, 2, 0, 0, 0], 'query': 3},
#   'output': 7},
#  {'input': {'cards': [8, 8, 6, 6, 6, 6, 6, 6, 3, 2, 2, 2, 0, 0, 0],
#    'query': 6},
#   'output': 2}]

# %%
def locate_card(cards, query):
    # Create a variable position with the value 0
    position = 0
    
    # Set up a loop for repetition
    while position < len(cards):
        if query not in cards:
            return -1
        # Check if element at the current position matche the query
        if cards[position] == query:
            
            # Answer found! Return and exit..
            return position
        
        # Increment the position
        position += 1
        
    return -1

# %%
from jovian.pythondsa import evaluate_test_case
from jovian.pythondsa import evaluate_test_cases

# %%
for test in tests:
    result = locate_card(**test['input'])
    print(f"Input: {test['input']}, Expected Output: {test['output']}, Actual Output: {result}, Test Passed: {result == test['output']}")
# Out:
# Input: {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 7}, Expected Output: 3, Actual Output: 3, Test Passed: True
# Input: {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 1}, Expected Output: 6, Actual Output: 6, Test Passed: True
# Input: {'cards': [4, 2, 1, -1], 'query': 4}, Expected Output: 0, Actual Output: 0, Test Passed: True
# Input: {'cards': [3, -1, -9, -127], 'query': -127}, Expected Output: 3, Actual Output: 3, Test Passed: True
# Input: {'cards': [6], 'query': 6}, Expected Output: 0, Actual Output: 0, Test Passed: True
# Input: {'cards': [9, 7, 5, 2, -9], 'query': 4}, Expected Output: -1, Actual Output: -1, Test Passed: True
# Input: {'cards': [], 'query': 7}, Expected Output: -1, Actual Output: -1, Test Passed: True
# Input: {'cards': [8, 8, 6, 6, 6, 6, 6, 3, 2, 2, 2, 0, 0, 0], 'query': 3}, Expected Output: 7, Actual Output: 7, Test Passed: True
# ...

# %%
evaluate_test_case(locate_card, test)
# Out:
# Input:
# {'cards': [8, 8, 6, 6, 6, 6, 6, 6, 3, 2, 2, 2, 0, 0, 0], 'query': 6}
#
# Expected Output:
# 2
#
#
# Actual Output:
# 2
#
# Execution Time:
# 0.003 ms
#
# Test Result:
# PASSED
# (2, True, 0.003)

# %%
def locateing_card(cards, query):
    lo, hi = 0, len(cards) - 1
    
    while lo <= hi:
        mid = (lo + hi) // 2
        mid_number = cards[mid]
        
        print("lo:", lo, ", hi:", hi, ", mid:", mid, ", mid_number:", mid_number)
        
        if mid_number == query:
            return mid
        elif mid_number < query:
            hi = mid - 1  
        elif mid_number > query:
            lo = mid + 1
    
    return -1

# %%
evaluate_test_cases(locateing_card, tests)
# Out:
# TEST CASE #0
# lo: 0 , hi: 7 , mid: 3 , mid_number: 7
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 7}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.031 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
# lo: 0 , hi: 7 , mid: 3 , mid_number: 7
# lo: 4 , hi: 7 , mid: 5 , mid_number: 3
# lo: 6 , hi: 7 , mid: 6 , mid_number: 1
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 1}
#
# Expected Output:
# 6
#
#
# Actual Output:
# 6
#
# Execution Time:
# 0.07 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
# lo: 0 , hi: 3 , mid: 1 , mid_number: 2
# lo: 0 , hi: 0 , mid: 0 , mid_number: 4
#
# Input:
# {'cards': [4, 2, 1, -1], 'query': 4}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.044 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
# lo: 0 , hi: 3 , mid: 1 , mid_number: -1
# lo: 2 , hi: 3 , mid: 2 , mid_number: -9
# lo: 3 , hi: 3 , mid: 3 , mid_number: -127
#
# Input:
# ...

# %%
evaluate_test_case(locateing_card, tests[8])
# Out:
# Input:
# {'cards': [8, 8, 6, 6, 6, 6, 6, 6, 3, 2, 2, 2, 0, 0, 0], 'query': 6}
#
# Expected Output:
# 2
#
# lo: 0 , hi: 14 , mid: 7 , mid_number: 6
#
# Actual Output:
# 7
#
# Execution Time:
# 0.027 ms
#
# Test Result:
# FAILED
# (7, False, 0.027)

# %%
def test_location(cards, query, mid):
    mid_number = cards[mid]
    print("mid:", mid, ", mid_number:", mid_number)
    if mid_number == query:
        if mid-1 >= 0 and cards[mid-1] == query:
            return 'left'
        else:
            return 'found'
    elif mid_number < query:
        return 'left'
    else:
        return 'right'

def locateings_card(cards, query):
    lo, hi = 0, len(cards) - 1
    
    while lo <= hi:
        print("lo:", lo, ", hi:", hi)
        mid = (lo + hi) // 2
        result = test_location(cards, query, mid)
        
        if result == 'found':
            return mid
        elif result == 'left':
            hi = mid - 1
        elif result == 'right':
            lo = mid + 1
    return -1

# %%
evaluate_test_case(locateings_card, tests[8])
# Out:
# Input:
# {'cards': [8, 8, 6, 6, 6, 6, 6, 6, 3, 2, 2, 2, 0, 0, 0], 'query': 6}
#
# Expected Output:
# 2
#
# lo: 0 , hi: 14
# mid: 7 , mid_number: 6
# lo: 0 , hi: 6
# mid: 3 , mid_number: 6
# lo: 0 , hi: 2
# mid: 1 , mid_number: 8
# lo: 2 , hi: 2
# mid: 2 , mid_number: 6
#
# Actual Output:
# 2
#
# Execution Time:
# 0.106 ms
#
# Test Result:
# PASSED
# (2, True, 0.106)

# %%
evaluate_test_cases(locateings_card, tests)
# Out:
# TEST CASE #0
# lo: 0 , hi: 7
# mid: 3 , mid_number: 7
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 7}
#
# Expected Output:
# 3
#
#
# Actual Output:
# 3
#
# Execution Time:
# 0.03 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
# lo: 0 , hi: 7
# mid: 3 , mid_number: 7
# lo: 4 , hi: 7
# mid: 5 , mid_number: 3
# lo: 6 , hi: 7
# mid: 6 , mid_number: 1
#
# Input:
# {'cards': [13, 11, 10, 7, 4, 3, 1, 0], 'query': 1}
#
# Expected Output:
# 6
#
#
# Actual Output:
# 6
#
# Execution Time:
# 0.072 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
# lo: 0 , hi: 3
# mid: 1 , mid_number: 2
# lo: 0 , hi: 0
# mid: 0 , mid_number: 4
#
# Input:
# {'cards': [4, 2, 1, -1], 'query': 4}
#
# Expected Output:
# 0
#
#
# Actual Output:
# 0
#
# Execution Time:
# 0.045 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
# lo: 0 , hi: 3
# mid: 1 , mid_number: -1
# lo: 2 , hi: 3
# mid: 2 , mid_number: -9
# lo: 3 , hi: 3
# mid: 3 , mid_number: -127
#
# Input:
# ...

# %%
def locate_card_linear(cards, query):
    position = 0
    while position < len(cards):
        if cards[position] == query:
            return position
        position += 1
    return -1

# %%
large_test = {
    'input': {
        'cards': list(range(100000000, 0, -1)),
        'query': 2
    },
    'output': 9999998
    
}

# %%
result, passed, runtime = evaluate_test_case(locate_card_linear, large_test, display=False)

print("Result: {}\nPassed: {}\nExecution Time: {} ms".format(result, passed, runtime))
# Out:
# Result: 99999998
# Passed: False
# Execution Time: 5709.614 ms

# %%
result, passed, runtime = evaluate_test_case(locateings_card, large_test, display=False)

print("Result: {}\nPassed: {}\nExecution Time: {} ms".format(result, passed, runtime))
# Out:
# lo: 0 , hi: 99999999
# mid: 49999999 , mid_number: 50000001
# lo: 50000000 , hi: 99999999
# mid: 74999999 , mid_number: 25000001
# lo: 75000000 , hi: 99999999
# mid: 87499999 , mid_number: 12500001
# lo: 87500000 , hi: 99999999
# mid: 93749999 , mid_number: 6250001
# lo: 93750000 , hi: 99999999
# mid: 96874999 , mid_number: 3125001
# lo: 96875000 , hi: 99999999
# mid: 98437499 , mid_number: 1562501
# lo: 98437500 , hi: 99999999
# mid: 99218749 , mid_number: 781251
# lo: 99218750 , hi: 99999999
# mid: 99609374 , mid_number: 390626
# lo: 99609375 , hi: 99999999
# mid: 99804687 , mid_number: 195313
# lo: 99804688 , hi: 99999999
# mid: 99902343 , mid_number: 97657
# lo: 99902344 , hi: 99999999
# mid: 99951171 , mid_number: 48829
# lo: 99951172 , hi: 99999999
# mid: 99975585 , mid_number: 24415
# lo: 99975586 , hi: 99999999
# mid: 99987792 , mid_number: 12208
# lo: 99987793 , hi: 99999999
# mid: 99993896 , mid_number: 6104
# lo: 99993897 , hi: 99999999
# mid: 99996948 , mid_number: 3052
# ...
