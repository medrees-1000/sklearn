# %% [markdown]
# # Assignment 3 - Divide-n-Conquer Algorithms in Python
#
# _This assignment is a part of the course ["Data Structures and Algorithms in Python"](https://jovian.ai/learn/data-structures-and-algorithms-in-python)._
#
# In this assignment, you will implement Python dictionaries from scratch using hash tables.
#
# As you go through this notebook, you will find the symbol **???** in certain places. To complete this assignment, you must replace all the **???** with appropriate values, expressions or statements to ensure that the notebook runs properly end-to-end.
#
# **Guidelines**
#
# 1. Make sure to run all the code cells, otherwise you may get errors like `NameError` for undefined variables.
# 2. Do not change variable names, delete cells or disturb other existing code. It may cause problems during evaluation.
# 3. In some cases, you may need to add some code cells or new statements before or after the line of code containing the **???**.
# 4. Since you'll be using a temporary online service for code execution, save your work by running `jovian.commit` at regular intervals.
# 5. Questions marked **(Optional)** will not be considered for evaluation, and can be skipped. They are for your learning.
# 6. If you are stuck, you can ask for help on the [community forum] (TODO - add link). Post errors or ask for hints, but **please don't ask for OR share the full working answer code** on the forum.
# 7. There are some tests included with this notebook to help you test your implementation. However, after submission your code will be tested with some hidden test cases. Make sure to test your code exhaustively to cover all edge cases.
#
#
# **Important Links**
#
# * Submit your work here: TODO - Add link
# * Ask questions and get help: TODO - Add link
# * Lesson 3 video for review: TODO - Add link
# * Lesson 3 notebook for review: TODO - Add link

# %% [markdown]
# ### How to Run the Code and Save Your Work
#
# **Option 1: Running using free online resources (1-click, recommended)**: Click the **Run** button at the top of this page and select **Run on Binder**. You can also select "Run on Colab" or "Run on Kaggle", but you'll need to create an account on [Google Colab](https://colab.research.google.com) or [Kaggle](https://kaggle.com) to use these platforms.
#
#
# **Option 2: Running on your computer locally**: To run the code on your computer locally, you'll need to set up [Python](https://www.python.org) & [Conda](https://docs.conda.io/projects/conda/en/latest/user-guide/install/), download the notebook and install the required libraries. Click the **Run** button at the top of this page, select the **Run Locally** option, and follow the instructions.
#
# **Saving your work**: You can save a snapshot of the assignment to your [Jovian](https://jovian.ai) profile, so that you can access it later and continue your work. Keep saving your work by running `jovian.commit` from time to time.

# %%
project='python-divide-and-conquer-assignment'

# %% [markdown]
# ## Problem Statement - Polynomial Multiplication
#
# > Given two polynomials represented by two lists, write a function that efficiently multiplies given two polynomials. For example, the lists `[2, 0, 5, 7]` and `[3, 4, 2]` represent the polynomials $2 + 5x^2 + 7x^3$ and $3 + 4x + 2x^2$. Their product is

# %% [markdown]
# ## The Method
#
# Here's the systematic strategy we'll apply for solving problems:
#
# 1. State the problem clearly. Identify the input & output formats.
# 2. Come up with some example inputs & outputs. Try to cover all edge cases.
# 3. Come up with a correct solution for the problem. State it in plain English.
# 4. Implement the solution and test it using example inputs. Fix bugs, if any.
# 5. Analyze the algorithm's complexity and identify inefficiencies, if any.
# 6. Apply the right technique to overcome the inefficiency. Repeat steps 3 to 6.
#
# This approach is explained in detail in [Lesson 1](https://jovian.ai/learn/data-structures-and-algorithms-in-python/lesson/lesson-1-binary-search-linked-lists-and-complexity) of the course. Let's apply this approach step-by-step.

# %% [markdown]
# ## Solution
#
#
# ### 1. State the problem clearly. Identify the input & output formats.
#
# While this problem is stated clearly enough, it's always useful to try and express in your own words, in a way that makes it most clear for you.
#
#
# **Problem**
#
# > **My undertstanding** (From my undertanding was that we are getting two list and each number in the list has X and the degree of the X is according to the position of the number in the list, we have two get the product of the two lists and return a new list contaning the result of it, in this process we have to foil each number from the first list to all the numbers in the second list or vise versa makes no difference.)
#
# <br/>
#
#
#
# **Input**
#
# 1. **[2,0,5,7]**
# 2. **[3,4,2]**
#
# (add more if required)
#
#
# **Output**
#
# 1. **[6, 8, 19, 41, 38, 14]**
#
#
# (add more if required)
#
# <br/>
#
# Based on the above, we can now create a signature of our function:

# %%
def polynominal(poly1, poly2):
    pass

# %% [markdown]
# ### 2. Come up with some example inputs & outputs. Try to cover all edge cases.
#
# Our function should be able to handle any set of valid inputs we pass into it. Here's a list of some possible variations we might encounter:
#
# 1. **Negative numbers**
# 2. **One empty list**
# 3. **Both empty list**
# 4. **One element lists**
# 5. **All elements being 1**
#
# (add more if required)
#
#
# We'll express our test cases as dictionaries, to test them easily. Each dictionary will contain 2 keys: `input` (a dictionary itself containing one key for each argument to the function and `output` (the expected result from the function).

# %%
test1 = {
    'input': {
        'poly1': [1, 2],
        'poly2': [3, 4]
    },
    'output': [3, 10, 8]
}

test2 = {
    'input': {
        'poly1': [2, 0, 5, 7],
        'poly2': [3, 4, 2]
    },
    'output': [6, 8, 19, 41, 38, 14]
}

test3 = {
    'input': {
        'poly1': [1],
        'poly2': [5, 3]
    },
    'output': [5, 3]
}

test4 = {
    'input': {
        'poly1': [0, 0, 1],
        'poly2': [0, 0, 1]
    },
    'output': [0, 0, 0, 0, 1]
}

test5 = {
    'input': {
        'poly1': [3, 5, 0, 2],
        'poly2': [4, 1, -1]
    },
    'output': [12, 23, 2, 3, 2, -2]
}

test6 = {
    'input': {
        'poly1': [5, -2, 3],
        'poly2': [0, 4, -1]
    },
    'output': [0, 20, -13, 14, -3]
}

test7 = {
    'input': {
        'poly1': [1, 1, 1, 1, 1],
        'poly2': [1, 1, 1, 1, 1]
    },
    'output': [1, 2, 3, 4, 5, 4, 3, 2, 1]
}

test8 = {
    'input': {
        'poly1': [2, -1, 3, 7],
        'poly2': [4, 0, 1]
    },
    'output': [8, -4, 14, 27, 3, 7]
}

test9 = {
    'input': {
        'poly1': [],
        'poly2': []
    },
    'output': []
}

test10 = {
    'input': {
        'poly1': [7],
        'poly2': [5]
    },
    'output': [35]
}
test11 = {
    'input': {
        'poly1': [0, 0, 0],
        'poly2': [0, 0, 0]
    },
    'output': [0, 0, 0, 0, 0]
}

# %%
tests = [test1, test2, test3, test4, test5, test6, test7, test8, test9, test10, test11]

# %% [markdown]
# ### 3. Come up with a correct solution for the problem. State it in plain English.
#
# Our first goal should always be to come up with a _correct_ solution to the problem, which may not necessarily be the most _efficient_ solution. Come with a correct solution and explain it in simple words below:
#
# 1. **First we will make a variable result size to alredy amke sure how many elemts there should be in the result this can be achived by adding the len of both list minus 1, because the degree is reprensted as m-1 and n-1 , M and N being the size of the lst**
# 2. **then we intialze the result variable and make a list which has zeros time the result size variable**
# 3. **we loop over the len of the list1**
# 4. **then we loop over list2**
# 5. **we put result[num + num2] as index and add the profuct of the two number on that index**
#
# (add more steps if required)
#
#
# Let's save and upload our work before continuing.

# %% [markdown]
# ###  4. Implement the solution and test it using example inputs. Fix bugs, if any.

# %%
def polynominal(poly1, poly2):
    result_size = len(poly1) + len(poly2) - 1
    result = [0] * result_size
    
    for num in range(len(poly1)):
        for num2 in range(len(poly2)):
            result[num + num2] += (poly1[num] * poly2[num2])
    
    return result

# %%
polynominal([2,0,5,7], [3,4,2])
# Out:
# [6, 8, 19, 41, 38, 14]

# %%
from jovian.pythondsa import evaluate_test_cases

results = evaluate_test_cases(polynominal, tests)
# Out:
# TEST CASE #0
#
# Input:
# {'poly1': [1, 2], 'poly2': [3, 4]}
#
# Expected Output:
# [3, 10, 8]
#
#
# Actual Output:
# [3, 10, 8]
#
# Execution Time:
# 0.005 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
#
# Input:
# {'poly1': [2, 0, 5, 7], 'poly2': [3, 4, 2]}
#
# Expected Output:
# [6, 8, 19, 41, 38, 14]
#
#
# Actual Output:
# [6, 8, 19, 41, 38, 14]
#
# Execution Time:
# 0.003 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
#
# Input:
# {'poly1': [1], 'poly2': [5, 3]}
#
# Expected Output:
# [5, 3]
#
#
# Actual Output:
# [5, 3]
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
#
# Input:
# {'poly1': [0, 0, 1], 'poly2': [0, 0, 1]}
#
# Expected Output:
# [0, 0, 0, 0, 1]
#
#
# Actual Output:
# [0, 0, 0, 0, 1]
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #4
#
# Input:
# {'poly1': [3, 5, 0, 2], 'poly2': [4, 1, -1]}
#
# Expected Output:
# [12, 23, 2, 3, 2, -2]
#
#
# Actual Output:
# [12, 23, 2, 3, 2, -2]
#
# Execution Time:
# 0.002 ms
# ...

# %% [markdown]
# ### 5. Analyze the algorithm's complexity and identify inefficiencies, if any.

# %% [markdown]
# Time Complexity:
# The time complexity of this function is O(n * m), where n is the length of `poly1` and m is the length of `poly2`. This is because there are two nested loops: the outer loop iterates over each coefficient in `poly1`, and the inner loop iterates over each coefficient in `poly2`. For each pair of coefficients, a multiplication and an addition operation are performed, leading to a total of n * m operations.

# %% [markdown]
# If both polynomials have similar lengths (i.e., 𝑛≈𝑚), the complexity simplifies to:O(n^2)

# %% [markdown]
# ### 6. Apply the right technique to overcome the inefficiency. Repeat steps 3 to 6.

# %% [markdown]
# ## Karatsuba Algorithm for Polynomial Multiplication
#
# We will use the **Karatsuba algorithm** to efficiently multiply two polynomials. This algorithm is significantly faster than the naive approach, reducing the time complexity from **O(n²) to O(n^log₂3)**. By breaking the problem into smaller subproblems, it optimizes the multiplication process, making it ideal for large polynomials.

# %%
def karatsuba(poly1, poly2):
    """
    This function ensures we multiply two polynomials , but we this algorithm we only do three mutplication instead of four
    and the Karatsuba algorithm for polynomial multiplication has a time complexity of O(n^log2(3)), which is approximately O(n^1.585).

    Args:
        poly1 (list): cosist of numbers
        poly2 (list): cosist of number

    Returns:
        list: it contains the multiplication of two polynomails result
    
    Side Note:
     you can split this into more fucntion to make it easy but it was alredy cinfusing for me so i didn't wanted to split 
        """
    if not poly1 or not poly2:
        return []  

    #If either polynomial has only one element
    if len(poly1) == 1:
        return [poly1[0] * element for element in poly2]
    if len(poly2) == 1:
        return [poly2[0] * element for element in poly1]

    #  If both polynomials contain only zeros, return the length zero polynomial
    if all(x == 0 for x in poly1) and all(x == 0 for x in poly2):
        return [0] * (len(poly1) + len(poly2) - 1)

    # Determine the required length for multiplication
    n = len(poly1) + len(poly2) - 1
    print('lenght of n: ', n)
    m = 1
    while m < max(len(poly1), len(poly2)):  
        m *= 2

    # Pad polynomials with zeros to length m
    poly1 += [0] * (m - len(poly1))
    poly2 += [0] * (m - len(poly2))
    
    
    # Splitting the polynomials by the middle elements  
    mid = m // 2
    low1, high1 = poly1[:mid], poly1[mid:]
    low2, high2 = poly2[:mid], poly2[mid:]

    # Recursively compute sub-results
    z0 = karatsuba(low1, low2)  
    z2 = karatsuba(high1, high2)  

    # Compute sum of lower and higher parts
    sum1 = [a + b for a, b in zip(low1, high1)]
    sum2 = [a + b for a, b in zip(low2, high2)]
    z1 = karatsuba(sum1, sum2) 

    # Compute z1 - z0 - z2 safely
    for i in range(len(z0)):
        z1[i] -= z0[i]
    for i in range(len(z2)):
        z1[i] -= z2[i]

    # Construct the final result
    result = [0] * (2 * m - 1)

    for i in range(len(z0)):
        result[i] += z0[i]
    for i in range(len(z1)):
        result[i + mid] += z1[i]
    for i in range(len(z2)):
        result[i + 2 * mid] += z2[i]

    # Trim excess padding and return the result
    return result[:n]

# %%
from jovian.pythondsa import evaluate_test_case

evaluate_test_case(karatsuba, test11)
# Out:
# Input:
# {'poly1': [0, 0, 0], 'poly2': [0, 0, 0]}
#
# Expected Output:
# [0, 0, 0, 0, 0]
#
#
# Actual Output:
# [0, 0, 0, 0, 0]
#
# Execution Time:
# 0.007 ms
#
# Test Result:
# PASSED
# ([0, 0, 0, 0, 0], True, 0.007)

# %%
evaluate_test_cases(karatsuba, tests)
# Out:
# TEST CASE #0
# lenght of n:  3
#
# Input:
# {'poly1': [1, 2], 'poly2': [3, 4]}
#
# Expected Output:
# [3, 10, 8]
#
#
# Actual Output:
# [3, 10, 8]
#
# Execution Time:
# 0.025 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
# lenght of n:  6
# lenght of n:  3
# lenght of n:  3
# lenght of n:  3
#
# Input:
# {'poly1': [2, 0, 5, 7], 'poly2': [3, 4, 2, 0]}
#
# Expected Output:
# [6, 8, 19, 41, 38, 14]
#
#
# Actual Output:
# [6, 8, 19, 41, 38, 14]
#
# Execution Time:
# 0.042 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
#
# Input:
# {'poly1': [1], 'poly2': [5, 3]}
#
# Expected Output:
# [5, 3]
#
#
# Actual Output:
# [5, 3]
#
# Execution Time:
# 0.001 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
# lenght of n:  5
# lenght of n:  3
# lenght of n:  3
#
# Input:
# {'poly1': [0, 0, 1, 0], 'poly2': [0, 0, 1, 0]}
#
# Expected Output:
# [0, 0, 0, 0, 1]
#
#
# Actual Output:
# [0, 0, 0, 0, 1]
#
# Execution Time:
# 0.029 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #4
# lenght of n:  6
# ...

# %% [markdown]
# ### 7. Come up with a correct solution for the problem. State it in plain English.
#
# Come with the optimized correct solution and explain it in simple words below:
#
# 1. **???**
# 2. **???**
# 3. **???**
# 4. **???**
# 5. **???**
#
# (add more steps if required)
#
#
# Let's save and upload our work before continuing.

# %% [markdown]
# ### 8. Implement the solution and test it using example inputs. Fix bugs, if any.

# %% [markdown]
# ### 9. Analyze the algorithm's complexity and identify inefficiencies, if any.
