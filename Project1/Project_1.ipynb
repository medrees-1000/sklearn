# %% [markdown]
# # **Project 1**

# %% [markdown]
# # Learning Objectives
#
# - Explore and glean insights from a real dataset using pandas
# - Practice using pandas for exploratory analysis, information gathering, and discovery
# - Practice cleaning data and answering questions

# %% [markdown]
# # Dataset
#
# You are to analyze campaign contributions to the 2016 U.S. presidential primary races made in California. Use the csv file located here: https://drive.google.com/file/d/1Lgg-PwXQ6TQLDowd6XyBxZw5g1NGWPjB/view?usp=sharing. You should download and save this file in the same folder as this notebook is stored.  This file originally came from the U.S. Federal Election Commission (https://www.fec.gov/).
#
# Documentation for this data can be found here: https://drive.google.com/file/d/11o_SByceenv0NgNMstM-dxC1jL7I9fHL/view?usp=sharing

# %% [markdown]
# When you upload the dataset to Colab, it will take approximately 2-3 minutes to load. **Do not run the code cell under "Setup" once the data has fully uploaded.**

# %% [markdown]
# # Data Questions
#
# You are working for a California state-wide election campaign. Your boss wants you to examine historic 2016 election contribution data to see what zipcodes are more supportive of fundraising for your candidate.
#
# Your boss asks you to filter out some of the records:
# - Only use primary 2016 contribution data.
# - Concentrate on Bernie Sanders as a candidate.
#
# The questions your boss wants answered is:
# - Which zipcode (5-digit zipcode) had the highest count of contributions and the most dollar amount?
# - What day(s) of the month do most people donate?

# %% [markdown]
# # Setup
#
# Run the cell below as it will load the data into a pandas dataframe named `contrib`. Note that a custom date parser is defined to speed up loading. If Python were to guess the date format, it would take even longer to load.

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# These commands below set some options for pandas and to have matplotlib show the charts in the notebook
pd.set_option('display.max_rows', 1000)
pd.options.display.float_format = '{:,.2f}'.format

# Define a date parser to pass to read_csv
d = lambda x: datetime.strptime(x, '%d-%b-%y')

# Load the data in chunks
chunk_size = 100000
contrib = pd.read_csv('P00000001-CA.csv', index_col=False, parse_dates=['contb_receipt_dt'], date_parser=d)

# Note - for now, it is okay to ignore the warning about mixed types.
# Out:
# C:\Users\idree\AppData\Local\Temp\ipykernel_16760\3403177661.py:14: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   contrib = pd.read_csv('P00000001-CA.csv', index_col=False, parse_dates=['contb_receipt_dt'], date_parser=d)
# C:\Users\idree\AppData\Local\Temp\ipykernel_16760\3403177661.py:14: DtypeWarning: Columns (6,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   contrib = pd.read_csv('P00000001-CA.csv', index_col=False, parse_dates=['contb_receipt_dt'], date_parser=d)

# %% [markdown]
# **For all questions, please do not alter any cells that already exist. However, you can add as many code or text cells as you need to answer the questions.**

# %% [markdown]
# ***
# # **Part 1: Initial Data Checks (50 points)**
#
# First, we will take a preliminary look at the data to check that it was loaded correctly and contains the info we need.

# %%
# checking out the table 
contrib.head(5)
# Out:
#      cmte_id    cand_id                  cand_nm          contbr_nm  \
# 0  C00575795  P00003392  Clinton, Hillary Rodham         AULL, ANNE
# 1  C00575795  P00003392  Clinton, Hillary Rodham  CARROLL, MARYJEAN
# 2  C00575795  P00003392  Clinton, Hillary Rodham   GANDARA, DESIREE
# 3  C00577130  P60007168         Sanders, Bernard          LEE, ALAN
# 4  C00577130  P60007168         Sanders, Bernard   LEONELLI, ODETTE
#
#      contbr_city contbr_st     contbr_zip            contbr_employer  \
# 0       LARKSPUR        CA 949,391,913.00                        NaN
# 1        CAMBRIA        CA 934,284,638.00                        NaN
# 2        FONTANA        CA 923,371,507.00                        NaN
# 3      CAMARILLO        CA 930,111,214.00  AT&T GOVERNMENT SOLUTIONS
# 4  REDONDO BEACH        CA 902,784,310.00   VERICOR ENTERPRISES INC.
#
#    contbr_occupation  contb_receipt_amt contb_receipt_dt receipt_desc memo_cd  \
# 0            RETIRED              50.00       2016-04-26          NaN       X
# 1            RETIRED             200.00       2016-04-20          NaN       X
# 2            RETIRED               5.00       2016-04-02          NaN       X
# 3  SOFTWARE ENGINEER              40.00       2016-03-04          NaN     NaN
# 4         PHARMACIST              35.00       2016-03-05          NaN     NaN
#
#                              memo_text form_tp  file_num      tran_id  \
# 0               * HILLARY VICTORY FUND    SA18   1091718     C4768722
# 1               * HILLARY VICTORY FUND    SA18   1091718     C4747242
# 2               * HILLARY VICTORY FUND    SA18   1091718     C4666603
# 3  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404  VPF7BKWA097
# 4  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404  VPF7BKX3MB3
#
#   election_tp
# 0       P2016
# 1       P2016
# 2       P2016
# 3       P2016
# 4       P2016

# %% [markdown]
# **Question 1:**
#
# Print the *shape* of the data. Does this match the expectation? (2 points)

# %% [markdown]
# **Answer 1**
#
# yes it does match the expectation

# %%
# Answerfor the first question  
contrib.shape
# Out:
# (1125659, 18)

# %% [markdown]
# **Question 2:**
#
# Print a list of column names. Are all the columns included that are in the documentation? (2 points)

# %% [markdown]
# **Answer 2**
#
# Yes everything is included you can see it below

# %%
# all of the following are the columns in the dataset
contrib.columns.to_list()
# Out:
# ['cmte_id',
#  'cand_id',
#  'cand_nm',
#  'contbr_nm',
#  'contbr_city',
#  'contbr_st',
#  'contbr_zip',
#  'contbr_employer',
#  'contbr_occupation',
#  'contb_receipt_amt',
#  'contb_receipt_dt',
#  'receipt_desc',
#  'memo_cd',
#  'memo_text',
#  'form_tp',
#  'file_num',
#  'tran_id',
#  'election_tp']

# %% [markdown]
# **Question 3:**
#
# Print out the first five rows of the dataset. How do the columns `cand_id`, `cand_nm` and `contbr_st` look? (3 points)

# %% [markdown]
# **answer 3**
#
# cand_id: This is an unique id for each person like Hilary, Sanders
#
# cand_nm: This holds the First, Middle, and last name of the person
#
# contbr_st: I belive this is the state name abbrevation like CA is Califronia

# %%
# Exploring these 3 colunms 
contrib.head(5)
# Out:
#      cmte_id    cand_id                  cand_nm          contbr_nm  \
# 0  C00575795  P00003392  Clinton, Hillary Rodham         AULL, ANNE
# 1  C00575795  P00003392  Clinton, Hillary Rodham  CARROLL, MARYJEAN
# 2  C00575795  P00003392  Clinton, Hillary Rodham   GANDARA, DESIREE
# 3  C00577130  P60007168         Sanders, Bernard          LEE, ALAN
# 4  C00577130  P60007168         Sanders, Bernard   LEONELLI, ODETTE
#
#      contbr_city contbr_st     contbr_zip            contbr_employer  \
# 0       LARKSPUR        CA 949,391,913.00                        NaN
# 1        CAMBRIA        CA 934,284,638.00                        NaN
# 2        FONTANA        CA 923,371,507.00                        NaN
# 3      CAMARILLO        CA 930,111,214.00  AT&T GOVERNMENT SOLUTIONS
# 4  REDONDO BEACH        CA 902,784,310.00   VERICOR ENTERPRISES INC.
#
#    contbr_occupation  contb_receipt_amt contb_receipt_dt receipt_desc memo_cd  \
# 0            RETIRED              50.00       2016-04-26          NaN       X
# 1            RETIRED             200.00       2016-04-20          NaN       X
# 2            RETIRED               5.00       2016-04-02          NaN       X
# 3  SOFTWARE ENGINEER              40.00       2016-03-04          NaN     NaN
# 4         PHARMACIST              35.00       2016-03-05          NaN     NaN
#
#                              memo_text form_tp  file_num      tran_id  \
# 0               * HILLARY VICTORY FUND    SA18   1091718     C4768722
# 1               * HILLARY VICTORY FUND    SA18   1091718     C4747242
# 2               * HILLARY VICTORY FUND    SA18   1091718     C4666603
# 3  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404  VPF7BKWA097
# 4  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404  VPF7BKX3MB3
#
#   election_tp
# 0       P2016
# 1       P2016
# 2       P2016
# 3       P2016
# 4       P2016

# %% [markdown]
# **Question 4:**
#
# Print out the values for the column `election_tp`. In your own words, based on the documentation, what information does the `election_tp` variable contain? Do the values in the column match the documentation? (3 points)

# %% [markdown]
# **Answer 4**
#
# i belive this stands for election 2016 like p2016 = presidential election 2016
# and yes they do match the columns in the dataset

# %%
# Demonstration of the my answer from the dataset 
contrib['election_tp'].head(5)
# Out:
# 0    P2016
# 1    P2016
# 2    P2016
# 3    P2016
# 4    P2016
# Name: election_tp, dtype: object

# %% [markdown]
# **Question 5:**
#
# Print out the datatypes for all of the columns. What are the datatypes for the `contbr_zip`, `contb_receipt_amt`, `contb_receipt_dt`? (5 points)

# %% [markdown]
# **Answer 5**
#
# `contbr_zip` : object
#
# `contb_receipt_amt`: Float64
#
# `contb_receipt_dt`: datetime64[ns]

# %%
#showing the data types
contrib.dtypes
# Out:
# cmte_id                      object
# cand_id                      object
# cand_nm                      object
# contbr_nm                    object
# contbr_city                  object
# contbr_st                    object
# contbr_zip                   object
# contbr_employer              object
# contbr_occupation            object
# contb_receipt_amt           float64
# contb_receipt_dt     datetime64[ns]
# receipt_desc                 object
# memo_cd                      object
# memo_text                    object
# form_tp                      object
# file_num                      int64
# tran_id                      object
# election_tp                  object
# dtype: object

# %% [markdown]
# **Question 6:**
#
# What columns have the most nulls?  Would you recommend to drop any columns based on the number of nulls? (5 points)
#
# *Hint:* Use the .isna() and .sum() functions together

# %% [markdown]
# **Answer 6**
#
# contbr_employer       157902,
# contbr_occupation      10399,
# receipt_desc         1110614,
# memo_cd               981391,
# memo_text             624511,
# election_tp             1425,
#
# `these has the most null `
#
# contbr_city               26,
# contbr_zip                95,
#
# `these are the lest none `
#
# i can only suggest to drop one of the least one because if you drop the one with the most it could effect your dataset plus it depends on what you need it for and what are you looking for so the circumstance matters

# %%
contrib.isnull().sum()
# Out:
# cmte_id                    0
# cand_id                    0
# cand_nm                    0
# contbr_nm                  0
# contbr_city               26
# contbr_st                  0
# contbr_zip                95
# contbr_employer       157902
# contbr_occupation      10399
# contb_receipt_amt          0
# contb_receipt_dt           0
# receipt_desc         1110614
# memo_cd               981391
# memo_text             624511
# form_tp                    0
# file_num                   0
# tran_id                    0
# election_tp             1425
# dtype: int64

# %% [markdown]
# **Question 7:**
#
# A column we know that we want to use is the cand_nm column.  From the documentation each candidate is a unique candidate id also. Check data quality of `cand_id` column to see if it matches `cand_nm` column. Specifically check to ensure our targetted candidate 'Bernard Sanders' always has the same cand_id throughout. Any issues with `cand_nm` matching `cand_id`? (5 points)
#
# *Hint:* Look at the value counts for candidate ID and name pairs.

# %% [markdown]
# **Answer 7**
#
# i showed that there is equal nunique ids and names, and sanders is always with the same id number

# %%
candd_id = contrib['cand_id'].nunique()
cond_nm = contrib["cand_nm"].nunique()

print(candd_id, cond_nm)
# Out:
# 25 25

# %%
contrib[contrib['cand_nm'].str.contains('Sanders')].head(5)
# Out:
#      cmte_id    cand_id           cand_nm         contbr_nm    contbr_city  \
# 3  C00577130  P60007168  Sanders, Bernard         LEE, ALAN      CAMARILLO
# 4  C00577130  P60007168  Sanders, Bernard  LEONELLI, ODETTE  REDONDO BEACH
# 5  C00577130  P60007168  Sanders, Bernard  LEONELLI, ODETTE  REDONDO BEACH
# 6  C00577130  P60007168  Sanders, Bernard    LEOPARD, PATTI          VISTA
# 8  C00577130  P60007168  Sanders, Bernard      LEPKE, KELLY    WESTMINSTER
#
#   contbr_st     contbr_zip            contbr_employer  contbr_occupation  \
# 3        CA 930,111,214.00  AT&T GOVERNMENT SOLUTIONS  SOFTWARE ENGINEER
# 4        CA 902,784,310.00   VERICOR ENTERPRISES INC.         PHARMACIST
# 5        CA 902,784,310.00   VERICOR ENTERPRISES INC.         PHARMACIST
# 6        CA 920,842,849.00  ONSITE ENERGY CORPORATION    PROJECT MANAGER
# 8        CA 926,833,846.00                       NONE       NOT EMPLOYED
#
#    contb_receipt_amt contb_receipt_dt receipt_desc memo_cd  \
# 3              40.00       2016-03-04          NaN     NaN
# 4              35.00       2016-03-05          NaN     NaN
# 5             100.00       2016-03-06          NaN     NaN
# 6              25.00       2016-03-04          NaN     NaN
# 8              10.00       2016-03-05          NaN     NaN
#
#                              memo_text form_tp  file_num      tran_id  \
# 3  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404  VPF7BKWA097
# 4  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404  VPF7BKX3MB3
# 5  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404  VPF7BKYBXV4
# 6  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404  VPF7BKW04C1
# 8  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404  VPF7BKX3H59
#
#   election_tp
# 3       P2016
# 4       P2016
# 5       P2016
# 6       P2016
# 8       P2016

# %% [markdown]
# **Question 8:**
#
# Another area to check is to make sure all of the records are from California. Check the `contbr_st` column - are there any records outside of California based on `contbr_st`? (5 points)

# %% [markdown]
# **answer8**
# the unique values is 1 which shows all are from CA

# %%
contrib['contbr_st'].nunique()
# Out:
# 1

# %% [markdown]
# **Question 9:**
#
# The next column to check for the analysis is the `tran_id` column. This column could be the primary key so look for duplicates. How many duplicate entries are there? (5 points)
#
# *Hint:* Look at the where the tran id value counts are greater than 1

# %% [markdown]
# **Answer 9**
#
# i found the dupicates by finding the total tran_id and unique numbers of tran_id
#
# the total difference is = 3454
#
# which concludes there is dupicates

# %%
# check a few duplicated tran_id examples to see if there is a pattern for why there are duplicae entries
examples = ['ADB49CB248C174E298F0', 'A5602AD777C8C4632B5A', 'SA17.1131188', 'SA17.959311', 'C10357933', 'C9499151']
contrib[contrib['tran_id'].isin(examples)]
# Out:
#            cmte_id    cand_id                    cand_nm  \
# 40217    C00575449  P40003576                 Paul, Rand
# 40218    C00575449  P40003576                 Paul, Rand
# 41393    C00575449  P40003576                 Paul, Rand
# 42430    C00575449  P40003576                 Paul, Rand
# 42822    C00575449  P40003576                 Paul, Rand
# 42836    C00575449  P40003576                 Paul, Rand
# 44681    C00575449  P40003576                 Paul, Rand
# 44685    C00575449  P40003576                 Paul, Rand
# 141644   C00458844  P60006723               Rubio, Marco
# 252440   C00574624  P60006111  Cruz, Rafael Edward 'Ted'
# 370296   C00573519  P60005915        Carson, Benjamin S.
# 395742   C00575795  P00003392    Clinton, Hillary Rodham
# 397490   C00575795  P00003392    Clinton, Hillary Rodham
# 490321   C00458844  P60006723               Rubio, Marco
# 606135   C00458844  P60006723               Rubio, Marco
# 644054   C00575795  P00003392    Clinton, Hillary Rodham
# 759335   C00575795  P00003392    Clinton, Hillary Rodham
# 1124458  C00573519  P60005915        Carson, Benjamin S.
#
#                       contbr_nm   contbr_city contbr_st     contbr_zip  \
# 40217           BREED, PAUL MR.  SOLANA BEACH        CA      92,075.00
# 40218         PARKS, ROBERT MR.       HUGHSON        CA 953,260,412.00
# 41393         PARKS, ROBERT MR.       HUGHSON        CA 953,260,412.00
# 42430           BREED, PAUL MR.  SOLANA BEACH        CA      92,075.00
# 42822           BREED, PAUL MR.  SOLANA BEACH        CA      92,075.00
# 42836         PARKS, ROBERT MR.       HUGHSON        CA 953,260,412.00
# 44681           BREED, PAUL MR.  SOLANA BEACH        CA      92,075.00
# 44685         PARKS, ROBERT MR.       HUGHSON        CA 953,260,412.00
# 141644     GUERRA, MARIO A. MR.        DOWNEY        CA 902,422,240.00
# 252440      TRULIO, JOHN GEORGE   LOS ANGELES        CA      900491226
# 370296      SMITH, JAMES N. MR.      WHITTIER        CA 906,031,327.00
# 395742            GAIMS, HORACE   LOS ANGELES        CA 900,363,262.00
# 397490              FALK, PETER   LOS ANGELES        CA 900,461,037.00
# 490321     GUERRA, MARIO A. MR.        DOWNEY        CA      902422240
# 606135   PENROSE, JAMES ROE MR.   BAKERSFIELD        CA      933064251
# 644054              FALK, PETER   LOS ANGELES        CA 900,461,037.00
# 759335            GAIMS, HORACE   LOS ANGELES        CA 900,363,262.00
# 1124458          KLEIN, JODY A.  PALM SPRINGS        CA      922648114
#
#                      contbr_employer      contbr_occupation  \
# 40217                     NET BURNER               ENGINEER
# 40218                  SELF-EMPLOYED                 FARMER
# 41393                  SELF-EMPLOYED                 FARMER
# 42430                     NET BURNER               ENGINEER
# 42822                     NET BURNER               ENGINEER
# 42836                  SELF-EMPLOYED                 FARMER
# 44681                     NET BURNER               ENGINEER
# 44685                  SELF-EMPLOYED                 FARMER
# 141644   GALLAGHER INSURANCE BROKERS       INSURANCE BROKER
# 252440                       RETIRED                RETIRED
# 370296                       RETIRED                RETIRED
# 395742                           NaN       RETIRED MUSICIAN
# 397490                       RETIRED              PHYSICIAN
# 490321   GALLAGHER INSURANCE BROKERS       INSURANCE BROKER
# 606135             KAISER PERMANENTE              PHYSICIAN
# 644054         INFORMATION REQUESTED  INFORMATION REQUESTED
# 759335         INFORMATION REQUESTED  INFORMATION REQUESTED
# 1124458                      RETIRED                RETIRED
#
#          contb_receipt_amt contb_receipt_dt  \
# 40217               500.00       2015-09-30
# 40218               200.00       2015-09-30
# 41393               200.00       2015-09-30
# 42430               500.00       2015-09-30
# 42822               500.00       2015-09-30
# 42836               200.00       2015-09-30
# 44681               500.00       2015-09-30
# 44685               200.00       2015-09-30
# 141644            2,700.00       2016-01-29
# 252440               25.00       2016-02-14
# 370296               19.00       2015-11-16
# 395742              250.00       2016-08-22
# 397490              500.00       2016-08-22
# 490321            2,700.00       2016-01-29
# 606135               25.00       2016-02-16
# 644054              500.00       2016-08-22
# 759335              250.00       2016-08-22
# 1124458               7.00       2016-01-12
#
#                                   receipt_desc memo_cd  \
# 40217                                      NaN       X
# 40218                                      NaN       X
# 41393                                      NaN       X
# 42430                                      NaN       X
# 42822                                      NaN       X
# 42836                                      NaN       X
# 44681                                      NaN       X
# 44685                                      NaN       X
# 141644   REATTRIBUTION/REDESIGNATION REQUESTED     NaN
# 252440                                     NaN     NaN
# 370296                                     NaN     NaN
# 395742                                     NaN       X
# 397490                                     NaN       X
# 490321   SEE REATTRIBUTION/REDESIGNATION BELOW       X
# 606135                                     NaN     NaN
# 644054                                     NaN       X
# 759335                                     NaN     NaN
# 1124458                                    NaN     NaN
#
#                                      memo_text form_tp  file_num  \
# 40217                                      NaN   SA17A   1057795
# 40218                                      NaN   SA17A   1057795
# 41393                                      NaN   SA17A   1057796
# 42430                                      NaN   SA17A   1057796
# 42822                                      NaN   SA17A   1057799
# 42836                                      NaN   SA17A   1057799
# 44681                                      NaN   SA17A   1057798
# 44685                                      NaN   SA17A   1057798
# 141644   REATTRIBUTION/REDESIGNATION REQUESTED   SA17A   1051592
# 252440                                     NaN   SA17A   1071498
# 370296                                     NaN   SA17A   1057553
# 395742                    *BEST EFFORTS UPDATE   SA17A   1112134
# 397490                    *BEST EFFORTS UPDATE   SA17A   1112134
# 490321   SEE REATTRIBUTION/REDESIGNATION BELOW   SA17A   1056862
# 606135                                     NaN   SA17A   1056862
# 644054                  * HILLARY VICTORY FUND    SA18   1100718
# 759335                                     NaN   SA17A   1100718
# 1124458                                    NaN   SA17A   1073637
#
#                       tran_id election_tp
# 40217    ADB49CB248C174E298F0       P2016
# 40218    A5602AD777C8C4632B5A       G2016
# 41393    A5602AD777C8C4632B5A       G2016
# 42430    ADB49CB248C174E298F0       P2016
# 42822    ADB49CB248C174E298F0       P2016
# 42836    A5602AD777C8C4632B5A       G2016
# 44681    ADB49CB248C174E298F0       P2016
# 44685    A5602AD777C8C4632B5A       G2016
# 141644            SA17.959311       P2016
# 252440           SA17.1131188       P2016
# 370296            SA17.959311       P2016
# 395742               C9499151       G2016
# 397490              C10357933       G2016
# 490321            SA17.959311       P2016
# 606135           SA17.1131188       P2016
# 644054              C10357933       G2016
# 759335               C9499151       G2016
# 1124458          SA17.1131188       P2016

# %% [markdown]
# After examining a few of these duplicated tran_id's, there do not appear to be any patterns for why there are duplicate entries.

# %%
unique_id = contrib['tran_id'].nunique()
total_id = contrib['tran_id'].value_counts().sum()

total_id - unique_id
# Out:
# np.int64(3454)

# %% [markdown]
# **Question 10:**
#
# Another column to check is the `contb_receipt_amt` that shows the donation amounts. How many negative donations are included? What do negative donations mean? Please show at least pull a few rows to look at the records with negative donations. Do these records match with the expectation of why a negative donation would happen? (5 points)
#
# To assist you, please refer to the following:
#
# https://www.fec.gov/help-candidates-and-committees/filing-reports/redesignating-and-reattributing-contributions/
#
# Also, it may be useful to examine the 'receipt_desc' and 'memo_text' fields.

# %% [markdown]
# **answer 10**
#
# Negative donations can occur due to:
#
# Refunds or Returned Contributions: If a candidate's campaign realizes they received more money than allowed or from an ineligible donor, they might refund the excess amount or the entire contribution. This refund is recorded as a negative amount in the campaign's financial records, essentially "taking back" a portion or all of the original donation.
#
# Adjustment Errors: Occasionally, errors in the initial reporting of contributions may require adjustments. For example, if a contribution was initially overstated or reported twice, a negative entry would correct the campaign finance records.
#
# the thing i saw here was that the donation was made for the same election which is the general election
#
#
# and there are 11896 negative donation

# %%
contrib.loc[contrib['contb_receipt_amt'] < 0]["contb_receipt_amt"].count().sum()
# Out:
# np.int64(11896)

# %%
contrib.loc[contrib['contb_receipt_amt'] < 0]
# Out:
#            cmte_id    cand_id                    cand_nm  \
# 19       C00574624  P60006111  Cruz, Rafael Edward 'Ted'
# 23       C00574624  P60006111  Cruz, Rafael Edward 'Ted'
# 81       C00574624  P60006111  Cruz, Rafael Edward 'Ted'
# 190      C00574624  P60006111  Cruz, Rafael Edward 'Ted'
# 213      C00574624  P60006111  Cruz, Rafael Edward 'Ted'
# ...            ...        ...                        ...
# 1125008  C00574624  P60006111  Cruz, Rafael Edward 'Ted'
# 1125317  C00580399  P60008521   Christie, Christopher J.
# 1125427  C00574624  P60006111  Cruz, Rafael Edward 'Ted'
# 1125446  C00573519  P60005915        Carson, Benjamin S.
# 1125582  C00574624  P60006111  Cruz, Rafael Edward 'Ted'
#
#                     contbr_nm             contbr_city contbr_st  \
# 19           JOLLIFF, RICHARD                   CHICO        CA
# 23           JOLLIFF, RICHARD                   CHICO        CA
# 81           JOLLIFF, RICHARD                   CHICO        CA
# 190          NOWELL, DIANA L.  RANCHO SANTA MARGARITA        CA
# 213        LICHTY, ANDREW MR.               SAN DIEGO        CA
# ...                       ...                     ...       ...
# 1125008  NELSON, PETER C. MR.         SAN LUIS OBISPO        CA
# 1125317       ASCHER, STEPHEN                PASADENA        CA
# 1125427       HANSEN, WILLIAM                GLENDALE        CA
# 1125446        PECK, JOHN JR.         RANCHO SANTA FE        CA
# 1125582        FARRELL, PETER                LA JOLLA        CA
#
#             contbr_zip                     contbr_employer  \
# 19      959,289,507.00                       SELF EMPLOYED
# 23      959,289,507.00                       SELF EMPLOYED
# 81      959,289,507.00                       SELF EMPLOYED
# 190     926,884,928.00  CAPISTRAND UNIFIED SCHOOL DISTRICT
# 213     921,096,720.00                       SELF EMPLOYED
# ...                ...                                 ...
# 1125008      934018000                       SELF EMPLOYED
# 1125317      911013113                             MIRAMAR
# 1125427      912081507                             RETIRED
# 1125446      920670829                    PECK ENTERPRISES
# 1125582      920375633                              RESMED
#
#             contbr_occupation  contb_receipt_amt contb_receipt_dt  \
# 19                    RANCHER             -25.00       2016-04-29
# 23                    RANCHER            -150.00       2016-04-29
# 81                    RANCHER             -60.00       2016-04-14
# 190      LIBRARIAN TECHNICIAN            -100.00       2016-04-11
# 213               REAL ESTATE             -25.00       2016-04-30
# ...                       ...                ...              ...
# 1125008               DENTIST          -2,700.00       2015-07-31
# 1125317             EXECUTIVE          -2,700.00       2016-01-30
# 1125427               RETIRED          -5,400.00       2015-07-01
# 1125446             PRESIDENT          -2,700.00       2016-01-01
# 1125582              CHAIRMAN          -2,700.00       2015-08-28
#
#                      receipt_desc memo_cd                 memo_text form_tp  \
# 19       REDESIGNATION TO GENERAL       X  REDESIGNATION TO GENERAL   SA17A
# 23       REDESIGNATION TO GENERAL       X  REDESIGNATION TO GENERAL   SA17A
# 81       REDESIGNATION TO GENERAL       X  REDESIGNATION TO GENERAL   SA17A
# 190      REDESIGNATION TO GENERAL       X  REDESIGNATION TO GENERAL   SA17A
# 213      REDESIGNATION TO GENERAL       X  REDESIGNATION TO GENERAL   SA17A
# ...                           ...     ...                       ...     ...
# 1125008  REDESIGNATION TO GENERAL       X  REDESIGNATION TO GENERAL   SA17A
# 1125317   REATTRIBUTION TO SPOUSE       X   REATTRIBUTION TO SPOUSE   SA17A
# 1125427                       NaN     NaN              CHARGED BACK   SA17A
# 1125446  REDESIGNATION TO GENERAL       X  REDESIGNATION TO GENERAL   SA17A
# 1125582  REDESIGNATION TO GENERAL       X  REDESIGNATION TO GENERAL   SA17A
#
#          file_num         tran_id election_tp
# 19        1077664  SA17A.1826482B       P2016
# 23        1077664  SA17A.1826483B       P2016
# 81        1077664   SA17A.1827494       P2016
# 190       1077664  SA17A.1639830B       P2016
# 213       1077664  SA17A.1826888B       P2016
# ...           ...             ...         ...
# 1125008   1053893    SA17.466666B       P2016
# 1125317   1051204     SA17.A40065       P2016
# 1125427   1053893     SA17.440961       P2016
# 1125446   1073637    SA17.817713B       P2016
# 1125582   1053893    SA17.348532B       P2016
#
# [11896 rows x 18 columns]

# %% [markdown]
# **Question 11:**
#
# Another column to look at is the date of donation column. Are there any dates outside of the primary period (defined as '2014-01-01' to '2016-06-07')? Are the dates well-formatted for our analysis? (5 points)

# %% [markdown]
# **answer 11**
#
# yes there are dates outside of this and it is well formed for analysis

# %%
#contrib.loc[(contrib["contb_receipt_dt"] < '2016-06-07') & (contrib["contb_receipt_dt"] > '2014-01-01')]

# %%
contrib.loc[contrib["contb_receipt_dt"] < '2014-01-01']
# Out:
#         cmte_id    cand_id       cand_nm          contbr_nm contbr_city  \
# 9932  C00458844  P60006723  Rubio, Marco  WHEELER, MARY MS.    ATHERTON
# 9994  C00458844  P60006723  Rubio, Marco  WHEELER, MARY MS.    ATHERTON
#
#      contbr_st     contbr_zip contbr_employer  contbr_occupation  \
# 9932        CA 940,273,415.00   SELF-EMPLOYED  INTERIOR DESIGNER
# 9994        CA 940,273,415.00   SELF-EMPLOYED  INTERIOR DESIGNER
#
#       contb_receipt_amt contb_receipt_dt receipt_desc memo_cd  \
# 9932             -20.00       2013-11-05          NaN       X
# 9994              20.00       2013-11-05          NaN       X
#
#                         memo_text form_tp  file_num             tran_id  \
# 9932  TRANSFER FROM RUBIO VICTORY    SA18   1029436  SA18.631526.2.0615
# 9994  TRANSFER FROM RUBIO VICTORY    SA18   1029436  SA18.631526.3.0615
#
#      election_tp
# 9932       P2016
# 9994       G2016

# %%
contrib.loc[contrib["contb_receipt_dt"] > '2016-06-07']
# Out:
#            cmte_id    cand_id                    cand_nm           contbr_nm  \
# 14673    C00574624  P60006111  Cruz, Rafael Edward 'Ted'     RANDALL, DICK J
# 14682    C00605568  P20002671              Johnson, Gary           BOAL, ROB
# 14697    C00605568  P20002671              Johnson, Gary         LEE, JASCHA
# 14698    C00605568  P20002671              Johnson, Gary         LEE, JASCHA
# 14700    C00575795  P00003392    Clinton, Hillary Rodham         BAKER, JUDY
# ...            ...        ...                        ...                 ...
# 1123992  C00575795  P00003392    Clinton, Hillary Rodham  RANDALL, NANCY ENA
# 1123993  C00575795  P00003392    Clinton, Hillary Rodham       WRIGHT, LORNA
# 1123994  C00575795  P00003392    Clinton, Hillary Rodham      BALES, REBECCA
# 1123995  C00575795  P00003392    Clinton, Hillary Rodham   BELLINGER, MARTHA
# 1123996  C00580100  P80001571           Trump, Donald J.  DELLA DONNA, KADEE
#
#          contbr_city contbr_st     contbr_zip                 contbr_employer  \
# 14673      CUPERTINO        CA      95,014.00                             NaN
# 14682       OAK PARK        CA      91,377.00                         VENDAVO
# 14697     SANTA CRUZ        CA      95,065.00                           YAHOO
# 14698     SANTA CRUZ        CA      95,065.00                           YAHOO
# 14700      VACAVILLE        CA 956,873,433.00                             NaN
# ...              ...       ...            ...                             ...
# 1123992  BAKERSFIELD        CA      933124485                         RETIRED
# 1123993      BENICIA        CA      945101743                             NaN
# 1123994     PASADENA        CA      911051700  PASADENA HEALTHCARE CONSULTING
# 1123995    CLAREMONT        CA      917112219                             NaN
# 1123996   LONG BEACH        CA          90803                   SELF-EMPLOYED
#
#         contbr_occupation  contb_receipt_amt contb_receipt_dt receipt_desc  \
# 14673                 NaN          -5,400.00       2016-06-30       Refund
# 14682            ENGINEER              30.00       2016-07-20          NaN
# 14697             S/W ENG              88.45       2016-07-14          NaN
# 14698             S/W ENG             100.00       2016-07-24          NaN
# 14700             RETIRED               5.00       2016-07-25          NaN
# ...                   ...                ...              ...          ...
# 1123992  REGISTERED NURSE               5.00       2016-08-02          NaN
# 1123993           RETIRED              50.00       2016-08-09          NaN
# 1123994      HOSPITAL CFO             100.00       2016-08-31          NaN
# 1123995           RETIRED              75.00       2016-08-31          NaN
# 1123996       REAL ESTATE             250.00       2016-07-06          NaN
#
#         memo_cd               memo_text form_tp  file_num        tran_id  \
# 14673       NaN                     NaN   SB28A   1096256    SB28A.90932
# 14682       NaN                     NaN   SA17A   1096305    SA17A.50793
# 14697       NaN                     NaN   SA17A   1096305    SA17A.51414
# 14698       NaN                     NaN   SA17A   1096305    SA17A.51415
# 14700         X  * HILLARY VICTORY FUND    SA18   1109498       C8807328
# ...         ...                     ...     ...       ...            ...
# 1123992     NaN                     NaN   SA17A   1100718       C8235857
# 1123993     NaN                     NaN   SA17A   1100718       C8997947
# 1123994     NaN                     NaN   SA17A   1100718       C9829807
# 1123995     NaN                     NaN   SA17A   1100718       C9862797
# 1123996     NaN                     NaN   SA17A   1104813  SA17A.1627816
#
#         election_tp
# 14673           NaN
# 14682         G2016
# 14697         G2016
# 14698         G2016
# 14700         P2016
# ...             ...
# 1123992       G2016
# 1123993       G2016
# 1123994       G2016
# 1123995       G2016
# 1123996       P2016
#
# [451370 rows x 18 columns]

# %% [markdown]
# **Question 12:**
#
# Let's examine the ```contbr_zip``` field. The zip codes should be 5 digits and not contain any decimals.
#
# Look at the distribution of zip codes. Do they appear to be properly formatted? If not, give two examples of incorrectly formatted zip codes.
#
# (5 points)

# %% [markdown]
# **answer 12**
#
# no the zip codes are not well formatted they have decimals and more than five numbers in some instances as we can see below
#
# examples
# 0	949,391,913.00
#
# 1	934,284,638.00
#
# 2	923,371,507.00

# %%
contrib[['contbr_zip']]
# Out:
#             contbr_zip
# 0       949,391,913.00
# 1       934,284,638.00
# 2       923,371,507.00
# 3       930,111,214.00
# 4       902,784,310.00
# ...                ...
# 1125654      902781750
# 1125655      960270030
# 1125656      960270030
# 1125657      960270030
# 1125658      960270030
#
# [1125659 rows x 1 columns]

# %% [markdown]
# **At this stage, here is a list of columns that appear important to answer the boss's questions:**
#
# "tran_id", "cand_id", "cand_nm", "election_tp", "contbr_zip", "contbr_nm", "contb_receipt_amt", and "contb_receipt_date"
#
# **Here is a list of columns that do not appear important to answer the boss's questions:**
#
# "cmte_id", "contbr_city", "contbr_st", "contbr_employer", "contbr_occupation", "receipt_desc", "memo_cd", "memo_text", "form_tp", "file_num"

# %% [markdown]
# ***
# # **Part 2: Data Filtering and Data Quality Fixes (25 points)**
#
# Now that we have a basic understanding of the data, let's filter out the records we don't need and fix the data.

# %% [markdown]
# **Question 13:**
#
# From the dataset filter out (remove) any election_tp not in the primary election. Print/show the shape of the dataframe after the filtering is complete. (5 points)

# %%
tp = contrib[~contrib['election_tp'].isna()]
tp[tp["election_tp"].str.contains('P')]
tp.shape
# Out:
# (1124234, 18)

# %% [markdown]
# **Question 14:**
#
# From the dataset filter out (remove) any candidate that is not Bernie Sanders. Print/show the shape of the dataframe after the filtering is complete. (5 points)

# %% [markdown]
# **answer 14**
# the shape is 407171, 18

# %%
tp = tp.loc[tp["cand_nm"] == "Sanders, Bernard"]
tp.shape
# Out:
# (407171, 18)

# %% [markdown]
# **Question 15:**
#
# The `contbr_zip` column is not formatted well for our analysis.
#
# Make a new zipcode column that is the five-digit zipcodes. Filter out any records outside of California based on the zipcode. Print/show the shape of the dataframe after the filtering is complete. (10 points).
#
# **Note:**
#
# If you were conducting this analysis in the real world, you would have to research what the valid 5-digit zipcodes for California are!
#
# For ease of the assignment, I have done this research for you.
#
# **Valid CA zip codes ranges from 90001 to 96162.**
#
# I used the following source for this information:
#
# https://www.structnet.com/instructions/zip_min_max_by_state.html

# %% [markdown]
# **answer 15**
#
# the shape is
#
# (21995, 18)

# %%
contrib['contbr_zip'] = contrib['contbr_zip'].astype("string")
ca_zip_code_list = contrib['contbr_zip'].tolist()

# %%
tp = tp[tp["contbr_zip"].isin(ca_zip_code_list)]
tp.shape
# Out:
# (21995, 18)

# %% [markdown]
# **Question 16:**
#
# The receipt amount column has negative donations. After talking with your team, a decision was made that the best course of action is to remove these negative values so that the donation count and amount is more accurate. Print/show the shape of the dataframe after the filtering is complete. (5 points)

# %% [markdown]
# **answer 16**
#
# the shape is 21975, 8

# %% [markdown]
# Next, we will drop columns that were not needed for the filtering and will not be needed to answer the boss's questions. Please take a moment to see which columns can be dropped in the code cell below.

# %%
# drop columns that won't be used in the analysis

drop_cols = ["cmte_id", "contbr_city", "contbr_st", "contbr_employer", "contbr_occupation", "receipt_desc",
             "memo_cd", "memo_text", "form_tp", "file_num"]


#pre-drop dataframe shape
print("Pre-drop row count: ", contrib.shape[0])
print("Pre-drop column count: ", contrib.shape[1])

contrib = contrib.drop(drop_cols, axis=1)

#post-drop dataframe shape
print("Post-drop row count: ", contrib.shape[0])
print("Post-drop column count: ", contrib.shape[1])
# Out:
# Pre-drop row count:  1125659
# Pre-drop column count:  18
# Post-drop row count:  1125659
# Post-drop column count:  8

# %%
tp = tp.drop(drop_cols, axis=1)

# %%
tp = tp[tp["contb_receipt_amt"] >= 0]
tp.shape
# Out:
# (21975, 8)

# %% [markdown]
# ***
# # **3. Answering the questions (20 points)**
#
# Now that the data is cleaned and filterd - let's answer the two questions from your boss!

# %% [markdown]
# **Question 17:**
#
# Which zipcode had the highest count of contributions and the most dollar amount? (10 points)

# %% [markdown]
# **answer 17**
#
# the highest zipcode count is 44 for 921034727
#
# the  most dollar  is zip code 941151105  of total   10,000.00

# %%
tp.groupby("contbr_zip")["contb_receipt_amt"].count().sort_values(ascending=False)
# Out:
# contbr_zip
# 921034727    44
# 956286916    40
# 949202136    23
# 945561545    21
# 910241229    19
#              ..
# 961611625     1
# 961611178     1
# 961611168     1
# 961603052     1
# 900043704     1
# Name: contb_receipt_amt, Length: 12737, dtype: int64

# %%
tp.groupby("contbr_zip")["contb_receipt_amt"].sum().sort_values(ascending=False)
# Out:
# contbr_zip
# 941151105   10,000.00
# 900642333    5,500.00
# 904056216    5,000.00
# 941222751    4,000.00
# 941171713    3,050.00
#                ...
# 917703108        1.00
# 940051622        1.00
# 934361484        1.00
# 916062828        1.00
# 926833846        1.00
# Name: contb_receipt_amt, Length: 12737, dtype: float64

# %% [markdown]
# **Question 18:**
#
# What day(s) of the month do most people donate? (10 points)

# %% [markdown]
# the days with the most dollars
#
# 2016-03-09 :  155,276.00
#
# 2016-03-31  : 109,452.04
#
# 2016-03-14   : 81,398.03
#
# 2016-03-27   : 60,130.39
#
# 2015-09-30  :  53,730.37

# %%
tp.groupby("contb_receipt_dt")["contb_receipt_amt"].sum().sort_values(ascending = False).head(5)
# Out:
# contb_receipt_dt
# 2016-03-09   155,276.00
# 2016-03-31   109,452.04
# 2016-03-14    81,398.03
# 2016-03-27    60,130.39
# 2015-09-30    53,730.37
# Name: contb_receipt_amt, dtype: float64
